# %% [markdown]
# Export Metadata to FDGC Standard using Arcpy
# -------------------
#
#  - Find all GDBs in HSIP Gold folder in \\ontodar\urbis
#  - For each dataset export Metadata using the arcpy tool
#  - Keep file structure and write output xmls
#
# **MUST BE RUN IN PYTHON 2.7 32-bit -- Background Processing 64 bit has issues with connecting to GDBs**

# %%
import arcpy
from arcpy import env
import os.path as op
import os
OUTPUTDIR = r"C:\Users\nlh\Workspace\Urbis\notebooks\HSIPMetadata\Output"
BASEGDBDIR = r"\\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure"

#set local variables
dir = arcpy.GetInstallInfo("desktop")["InstallDir"]
translator = dir + r"Metadata\Translator\ARCGIS2FGDC.xml"

# find all of the gdbs
for root, dirs, files in os.walk(BASEGDBDIR):
    for d in dirs:
        if d.endswith(".gdb"):
            gdboutputdir = op.join(OUTPUTDIR, d.split('.')[0])
            if not op.exists(gdboutputdir):
                os.mkdir(gdboutputdir)
            arcpy.env.workspace = op.join(root, d)
            print "Processing", op.join(root,d)
            for fds in arcpy.ListDatasets('','feature') + ['']:
                for fc in arcpy.ListFeatureClasses('','',fds):
                    print "."
                    if not op.exists(op.join(gdboutputdir, "{0}.xml".format(fc))):
                        arcpy.ExportMetadata_conversion(fc, translator, op.join(gdboutputdir, "{0}.xml".format(fc)))
# Out:
#  Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\NaturalHazards\NaturalHazards.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\TransAir\TransAir.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\InfraAsset_List\InfrastructureAssetList(IAL).gdb
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\LawEnforcement\Law Enforcement.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\NatLevDb\National Levee DB.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\WaterSupply\WaterSupply.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\Chemicals\Chemical.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\NationalFloodHazardLayer\National_Flood_Hazard.gdb
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\Boundaries\Boundaries.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\Mining\Mining.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\Manufacturing\Manufacturing.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\TransGround\TransGround.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\Commercial\Commercial.gdb
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\Finance\Finance.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\Education\Education.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\Energy\Energy.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\FoodIndustry\FoodIndustry.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\Borders\Borders.gdb
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\MailShipping\MailShipping.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\TransWater\TransWater.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\PubHealth\PubHealth.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\Agriculture\Agriculture.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\Communications\Communications.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\EmergencyServ\EmergencyServ.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\Government\Government.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\PubVenues\PubVenues.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Processing \\ontodar\URBIS\HSIP_GOLD_2015\Data\Infrastructure\Geonames\Geonames.gdb
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
